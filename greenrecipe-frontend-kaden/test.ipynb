# %%
import plotly.express as px
import pandas as pd

df = px.data.gapminder().query("year == 2007").query("continent == 'Europe'")
df.loc[df['pop'] < 2.e6, 'country'] = 'Other countries' # Represent only large countries
fig = px.pie(df, values='pop', names='country', title='Population of European continent')
fig.show()

# %%
d = [
    {
        "co2": 1.2,
        "ingredient": "corn"
    },
    {
        "co2": 1.21,
        "ingredient": "beans"
    },
    {
        "co2": 4.22,
        "ingredient": "dates"
    },
    {
        "co2": 5.06,
        "ingredient": "tea"
    },
    {
        "co2": 3.01,
        "ingredient": "dates"
    },
    {
        "co2": 0.652,
        "ingredient": "spices"
    },
    {
        "co2": 3.56,
        "ingredient": "dates"
    },
    {
        "co2": 0.7,
        "ingredient": "french fries"
    },
    {
        "co2": 0.403,
        "ingredient": "black-eyed beans"
    },
    {
        "co2": 1.249,
        "ingredient": "baking soda"
    },
    {
        "co2": 0.602,
        "ingredient": "bay leaves"
    },
    {
        "co2": 0.652,
        "ingredient": "cardamom"
    },
    {
        "co2": 0.92,
        "ingredient": "chia seeds"
    },
    {
        "co2": 0.643,
        "ingredient": "cinnamon"
    },
    {
        "co2": 2.678,
        "ingredient": "macadamia nuts"
    },
    {
        "co2": 4.784,
        "ingredient": "mustard leaves"
    },
    {
        "co2": 2.678,
        "ingredient": "pecans"
    },
    {
        "co2": 2.518,
        "ingredient": "pine nuts"
    },
    {
        "co2": 0.92,
        "ingredient": "poppy seed"
    },
    {
        "co2": 0.692,
        "ingredient": "saffron"
    },
    {
        "co2": 2.267,
        "ingredient": "vanilin"
    },
    {
        "co2": 6.29,
        "ingredient": "cockles"
    },
    {
        "co2": 0.6,
        "ingredient": "wholegrain bread bun"
    },
    {
        "co2": 0.62,
        "ingredient": "wheat bread bun"
    },
    {
        "co2": 0.52,
        "ingredient": "bulgur"
    },
    {
        "co2": 0.44,
        "ingredient": "couscous"
    },
    {
        "co2": 0.44,
        "ingredient": "wholewheat noodles"
    },
    {
        "co2": 0.46,
        "ingredient": "wholegrain toast"
    },
    {
        "co2": 0.59,
        "ingredient": "wholegrain bread"
    },
    {
        "co2": 0.34,
        "ingredient": "all-purpose flour"
    },
    {
        "co2": 0.34,
        "ingredient": "wholewheat flour"
    },
    {
        "co2": 0.95,
        "ingredient": "walnuts"
    },
    {
        "co2": 0.22,
        "ingredient": "damson"
    },
    {
        "co2": 0.4,
        "ingredient": "lupin flour"
    },
    {
        "co2": 4.7985316,
        "ingredient": "cashew nuts"
    },
    {
        "co2": 1.7768884,
        "ingredient": "hazelnuts"
    },
    {
        "co2": 0.5924849,
        "ingredient": "chicory"
    },
    {
        "co2": 0.65,
        "ingredient": "quinoa"
    },
    {
        "co2": 2.25,
        "ingredient": "almonds"
    },
    {
        "co2": 19.7,
        "ingredient": "cocoa beans"
    },
    {
        "co2": 2.98,
        "ingredient": "coconut oil"
    },
    {
        "co2": 0.912,
        "ingredient": "coconut"
    },
    {
        "co2": 7.75,
        "ingredient": "coffee beans"
    },
    {
        "co2": 0.711,
        "ingredient": "beans"
    },
    {
        "co2": 0.711,
        "ingredient": "black beans"
    },
    {
        "co2": 0.711,
        "ingredient": "broad beans"
    },
    {
        "co2": 0.711,
        "ingredient": "fava beans"
    },
    {
        "co2": 0.711,
        "ingredient": "kidney beans"
    },
    {
        "co2": 0.711,
        "ingredient": "mung beans"
    },
    {
        "co2": 0.711,
        "ingredient": "navy beans"
    },
    {
        "co2": 0.711,
        "ingredient": "pinto beans"
    },
    {
        "co2": 0.711,
        "ingredient": "runner beans"
    },
    {
        "co2": 0.537,
        "ingredient": "beans"
    },
    {
        "co2": 0.537,
        "ingredient": "black beans"
    },
    {
        "co2": 0.537,
        "ingredient": "broad beans"
    },
    {
        "co2": 0.537,
        "ingredient": "fava beans"
    },
    {
        "co2": 0.537,
        "ingredient": "kidney beans"
    },
    {
        "co2": 0.537,
        "ingredient": "mung beans"
    },
    {
        "co2": 0.537,
        "ingredient": "navy beans"
    },
    {
        "co2": 0.537,
        "ingredient": "pinto beans"
    },
    {
        "co2": 0.537,
        "ingredient": "runner beans"
    },
    {
        "co2": 0.55,
        "ingredient": "black cod"
    },
    {
        "co2": 0.55,
        "ingredient": "cod"
    },
    {
        "co2": 0.55,
        "ingredient": "lingcod"
    },
    {
        "co2": 2.93,
        "ingredient": "john dory"
    },
    {
        "co2": 1.17,
        "ingredient": "linseed"
    },
    {
        "co2": 0.56,
        "ingredient": "corn"
    },
    {
        "co2": 0.528,
        "ingredient": "corn"
    },
    {
        "co2": 0.354,
        "ingredient": "corn"
    },
    {
        "co2": 1.41,
        "ingredient": "corn kernel"
    },
    {
        "co2": 1.52,
        "ingredient": "corn kernel"
    },
    {
        "co2": 1.03,
        "ingredient": "corn kernel"
    },
    {
        "co2": 0.928,
        "ingredient": "cornstarch"
    },
    {
        "co2": 0.728,
        "ingredient": "oats"
    },
    {
        "co2": 1.53,
        "ingredient": "peanuts"
    },
    {
        "co2": 0.403,
        "ingredient": "split peas"
    },
    {
        "co2": 0.744,
        "ingredient": "split peas"
    },
    {
        "co2": 0.444,
        "ingredient": "split peas"
    },
    {
        "co2": 1.63,
        "ingredient": "basmati rice"
    },
    {
        "co2": 1.63,
        "ingredient": "rice"
    },
    {
        "co2": 3.76,
        "ingredient": "soybeans"
    },
    {
        "co2": 0.774,
        "ingredient": "soybeans"
    },
    {
        "co2": 0.884,
        "ingredient": "soybeans"
    },
    {
        "co2": 0.632,
        "ingredient": "boysenberries"
    },
    {
        "co2": 0.632,
        "ingredient": "jostaberries"
    },
    {
        "co2": 0.632,
        "ingredient": "wheat berries"
    },
    {
        "co2": 0.6253,
        "ingredient": "brown sugar"
    },
    {
        "co2": 1.42,
        "ingredient": "sunflower seeds"
    },
    {
        "co2": 0.668,
        "ingredient": "sunflower seeds"
    },
    {
        "co2": 0.284,
        "ingredient": "sweetcorn"
    }
]

# %%
df = pd.DataFrame(d)

# %%
df.sort_values('co2',ascending=False)[:10]
# Out:
#           co2      ingredient
# 39  19.700000     cocoa beans
# 42   7.750000    coffee beans
# 21   6.290000         cockles
# 3    5.060000             tea
# 34   4.798532     cashew nuts
# 15   4.784000  mustard leaves
# 2    4.220000           dates
# 80   3.760000        soybeans
# 6    3.560000           dates
# 4    3.010000           dates

# %%
df.shape
# Out:
# (90, 2)
